# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Conjunto de Dados 'Titanic'

# %%
df = sns.load_dataset('titanic')

# %% [markdown]
# ## Dicionário de Dados

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_dict = pd.DataFrame([
    {
        "variavel": "survived",
        "descricao": "Se o passageiro sobreviveu ('0', '1')",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "pclass",
        "descricao": "Classe do passageiro ('1', '2', '3')",
        "tipo": "qualitativa",
        "subtipo": "ordinal",
    },{
        "variavel": "sex",
        "descricao": "Gênero do passageiro ('Female', 'Male')",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "age",
        "descricao": "Idade do passageiro em anos",
        "tipo": "quantitativa",
        "subtipo": "contínua",
    },{
        "variavel": "sibsp",
        "descricao": "Número de irmãos/cônjuges a bordo",
        "tipo": "quantitativa",
        "subtipo": "discreta",
    },{
        "variavel": "parch",
        "descricao": "Número de pais/filhos a bordo",
        "tipo": "quantitativa",
        "subtipo": "discreta",
    },{
        "variavel": "fare",
        "descricao": "Tarifa do passageiro",
        "tipo": "quantitativa",
        "subtipo": "contínua",
    },{
        "variavel": "embarked",
        "descricao": "Onde o passageiro embarcou no navio ('C', 'S', 'Q')",
        "tipo": "qualitativa",
        "subtipo": "ordinal",
    },{
        "variavel": "class",
        "descricao": "Classe do passageiro ('First', 'Second', 'Third')",
        "tipo": "qualitativa",
        "subtipo": "ordinal",
    },{
        "variavel": "Quem?",
        "descricao": "Se o cliente é fumante ('Yes', 'No')",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "adult_male",
        "descricao": "Homem Adulto?",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "deck",
        "descricao": "Convés?",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "embark_town",
        "descricao": "Cidade de embarque ('Southampton', 'Cherbourg', 'Queenstown')",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "alive",
        "descricao": "Vivo?",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "alone",
        "descricao": "Sozinho?",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    }
])

df_dict
# Out:
#        variavel                                          descricao  \
# 0      survived              Se o passageiro sobreviveu ('0', '1')
# 1        pclass               Classe do passageiro ('1', '2', '3')
# 2           sex            Gênero do passageiro ('Female', 'Male')
# 3           age                        Idade do passageiro em anos
# 4         sibsp                  Número de irmãos/cônjuges a bordo
# 5         parch                      Número de pais/filhos a bordo
# 6          fare                               Tarifa do passageiro
# 7      embarked  Onde o passageiro embarcou no navio ('C', 'S',...
# 8         class  Classe do passageiro ('First', 'Second', 'Third')
# 9         Quem?               Se o cliente é fumante ('Yes', 'No')
# 10   adult_male                                      Homem Adulto?
# 11         deck                                            Convés?
# 12  embark_town  Cidade de embarque ('Southampton', 'Cherbourg'...
# ...

# %% [markdown]
# ## Estatísticas Descritivas dos Dados

# %% [markdown]
# ### Variáveis Quantitativas

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ### Variáveis Qualitativas

# %%
df[['sex', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone']].mode()
# Out:
#     sex embarked  class  who  adult_male deck  embark_town alive  alone
# 0  male        S  Third  man        True    C  Southampton    no   True

# %%
qualitative_vars = ['sex', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone']

for variavel in qualitative_vars:
    valores_unicos = df[variavel].unique()
    for valor in valores_unicos:
        print(f"{variavel} - {valor}")
        subamostra = df[df[variavel] == valor]
        display(subamostra.describe())
        print("="*100)
# Out:
# sex - male
#          survived      pclass         age       sibsp       parch        fare
# count  577.000000  577.000000  453.000000  577.000000  577.000000  577.000000
# mean     0.188908    2.389948   30.726645    0.429809    0.235702   25.523893
# std      0.391775    0.813580   14.678201    1.061811    0.612294   43.138263
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   21.000000    0.000000    0.000000    7.895800
# 50%      0.000000    3.000000   29.000000    0.000000    0.000000   10.500000
# 75%      0.000000    3.000000   39.000000    0.000000    0.000000   26.550000
# max      1.000000    3.000000   80.000000    8.000000    5.000000  512.329200
# ...
# sex - female
#          survived      pclass         age       sibsp       parch        fare
# count  314.000000  314.000000  261.000000  314.000000  314.000000  314.000000
# mean     0.742038    2.159236   27.915709    0.694268    0.649682   44.479818
# ...

# %% [markdown]
# # Conjunto de Dados 'Tips'

# %%
df = sns.load_dataset('tips')

# %% [markdown]
# ## Dicionário de Dados

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Criação de um dicionário de dados

df_dict = pd.DataFrame([
    {
        "variavel": "total_bill",
        "descricao": "Valor total da conta",
        "tipo": "quantitativa",
        "subtipo": "contínua",
    },{
        "variavel": "tip",
        "descricao": "Valor da gorjeta",
        "tipo": "quantitativa",
        "subtipo": "contínua",
    },{
        "variavel": "sex",
        "descricao": "Gênero do cliente ('Female', 'Male')",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "smoker",
        "descricao": "Se o cliente é fumante ('Yes', 'No')",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "day",
        "descricao": "Dia da semana ('Sun', 'Thur', 'Fri', 'Sat')",
        "tipo": "qualitativa",
        "subtipo": "ordinal",
    },{
        "variavel": "time",
        "descricao": "Horário da refeição ('Lunch', 'Dinner')",
        "tipo": "qualitativa",
        "subtipo": "ordinal",
    },{
        "variavel": "size",
        "descricao": "Número de pessoas no grupo",
        "tipo": "quantitativa",
        "subtipo": "discreta",
    }
])

df_dict
# Out:
#      variavel                                    descricao          tipo  \
# 0  total_bill                         Valor total da conta  quantitativa
# 1         tip                             Valor da gorjeta  quantitativa
# 2         sex         Gênero do cliente ('Female', 'Male')   qualitativa
# 3      smoker         Se o cliente é fumante ('Yes', 'No')   qualitativa
# 4         day  Dia da semana ('Sun', 'Thur', 'Fri', 'Sat')   qualitativa
# 5        time      Horário da refeição ('Lunch', 'Dinner')   qualitativa
# 6        size                   Número de pessoas no grupo  quantitativa
#
#     subtipo
# 0  contínua
# 1  contínua
# 2   nominal
# 3   nominal
# 4   ordinal
# 5   ordinal
# 6  discreta

# %% [markdown]
# ## Estatísticas Descritivas dos Dados

# %% [markdown]
# ### Variáveis Quantitativas

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ### Variáveis Qualitativas

# %%
df[['sex', 'smoker', 'day', 'time']].mode()
# Out:
#     sex smoker  day    time
# 0  Male     No  Sat  Dinner

# %%
qualitative_vars = ['sex', 'smoker', 'day', 'time']

for variavel in qualitative_vars:
    valores_unicos = df[variavel].unique()
    for valor in valores_unicos:
        print(f"{variavel} - {valor}")
        subamostra = df[df[variavel] == valor]
        display(subamostra.describe())
        print("="*100)
# Out:
# sex - Female
#        total_bill        tip       size
# count   87.000000  87.000000  87.000000
# mean    18.056897   2.833448   2.459770
# std      8.009209   1.159495   0.937644
# min      3.070000   1.000000   1.000000
# 25%     12.750000   2.000000   2.000000
# 50%     16.400000   2.750000   2.000000
# 75%     21.520000   3.500000   3.000000
# max     44.300000   6.500000   6.000000
# ...
# sex - Male
#        total_bill         tip        size
# count  157.000000  157.000000  157.000000
# mean    20.744076    3.089618    2.630573
# std      9.246469    1.489102    0.955997
# min      7.250000    1.000000    1.000000
# 25%     14.000000    2.000000    2.000000
# 50%     18.350000    3.000000    2.000000
# 75%     24.710000    3.760000    3.000000
# max     50.810000   10.000000    6.000000
# ...
# smoker - No
#        total_bill         tip        size
# count  151.000000  151.000000  151.000000
# mean    19.188278    2.991854    2.668874
# std      8.255582    1.377190    1.017984
# ...
